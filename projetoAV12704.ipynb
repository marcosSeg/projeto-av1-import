# %% [markdown]
# <a href="https://colab.research.google.com/github/marcosSeg/projeto-av1-import/blob/main/projetoAV12704.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
plt.show()

# %%
#Importando dados
data = pd.read_table('https://archive.ics.uci.edu/ml/machine-learning-databases/image/segmentation.data')

print(len(data.columns))
# Out:
# 1

# %%
print(len(data.columns))

data = pd.read_table('https://archive.ics.uci.edu/ml/machine-learning-databases/image/segmentation.data',delim_whitespace=True, header=0)

data
# Out:
# 1
#                                                                         ;;;  \
# ;;;                                                *-* Last-edit:  11/21/90
# REGION-CENTROID-COL,REGION-CENTROID-ROW,REGION-... NaN NaN              NaN
# BRICKFACE,140.0,125.0,9,0.0,0.0,0.2777779,0.062... NaN NaN              NaN
# BRICKFACE,188.0,133.0,9,0.0,0.0,0.33333334,0.26... NaN NaN              NaN
# BRICKFACE,105.0,139.0,9,0.0,0.0,0.27777782,0.10... NaN NaN              NaN
# ...                                                                     ...
# GRASS,36.0,243.0,9,0.11111111,0.0,1.888889,1.85... NaN NaN              NaN
# GRASS,186.0,218.0,9,0.0,0.0,1.1666666,0.7444442... NaN NaN              NaN
# GRASS,197.0,236.0,9,0.0,0.0,2.4444444,6.829628,... NaN NaN              NaN
# GRASS,208.0,240.0,9,0.11111111,0.0,1.0555557,0.... NaN NaN              NaN
# GRASS,223.0,185.0,9,0.0,0.0,0.5,0.34960312,2.38... NaN NaN              NaN
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 212 entries, (';;;', '*-*', 'Last-edit:') to ('GRASS,223.0,185.0,9,0.0,0.0,0.5,0.34960312,2.3888886,2.0807757,12.962963,11.555555,9.777778,17.555555,-4.2222223,-9.555555,13.777778,17.555555,0.44541803,1.8388497', nan, nan)
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ;;;                1 non-null      object
#  1   -*-                1 non-null      object
#  2   Mode:Common-Lisp;  1 non-null      object
#  3   Base:10            1 non-null      object
#  4   -*-.1              1 non-null      object
# dtypes: object(5)
# memory usage: 19.1+ KB

# %%
print(len(data.columns))
# Out:
# 5

# %%
data = pd.read_table('https://archive.ics.uci.edu/ml/machine-learning-databases/image/segmentation.data',delim_whitespace=True, header=0)
data
# Out:
#                                                                         ;;;  \
# ;;;                                                *-* Last-edit:  11/21/90
# REGION-CENTROID-COL,REGION-CENTROID-ROW,REGION-... NaN NaN              NaN
# BRICKFACE,140.0,125.0,9,0.0,0.0,0.2777779,0.062... NaN NaN              NaN
# BRICKFACE,188.0,133.0,9,0.0,0.0,0.33333334,0.26... NaN NaN              NaN
# BRICKFACE,105.0,139.0,9,0.0,0.0,0.27777782,0.10... NaN NaN              NaN
# ...                                                                     ...
# GRASS,36.0,243.0,9,0.11111111,0.0,1.888889,1.85... NaN NaN              NaN
# GRASS,186.0,218.0,9,0.0,0.0,1.1666666,0.7444442... NaN NaN              NaN
# GRASS,197.0,236.0,9,0.0,0.0,2.4444444,6.829628,... NaN NaN              NaN
# GRASS,208.0,240.0,9,0.11111111,0.0,1.0555557,0.... NaN NaN              NaN
# GRASS,223.0,185.0,9,0.0,0.0,0.5,0.34960312,2.38... NaN NaN              NaN
#
# ...

# %%
data.select_dtypes(include='object')
# Out:
#                  ;;; -*- Mode:Common-Lisp; Base:10 -*-
# 0    ;;; *-* Last-edit: 11/21/90 15:28:30 by Brodle...
# 1    REGION-CENTROID-COL,REGION-CENTROID-ROW,REGION...
# 2    BRICKFACE,140.0,125.0,9,0.0,0.0,0.2777779,0.06...
# 3    BRICKFACE,188.0,133.0,9,0.0,0.0,0.33333334,0.2...
# 4    BRICKFACE,105.0,139.0,9,0.0,0.0,0.27777782,0.1...
# ..                                                 ...
# 207  GRASS,36.0,243.0,9,0.11111111,0.0,1.888889,1.8...
# 208  GRASS,186.0,218.0,9,0.0,0.0,1.1666666,0.744444...
# 209  GRASS,197.0,236.0,9,0.0,0.0,2.4444444,6.829628...
# 210  GRASS,208.0,240.0,9,0.11111111,0.0,1.0555557,0...
# 211  GRASS,223.0,185.0,9,0.0,0.0,0.5,0.34960312,2.3...
#
# [212 rows x 1 columns]

# %%
data = pd.read_table('https://archive.ics.uci.edu/ml/machine-learning-databases/image/segmentation.data')
data.head()
# Out:
#                ;;; -*- Mode:Common-Lisp; Base:10 -*-
# 0  ;;; *-* Last-edit: 11/21/90 15:28:30 by Brodle...
# 1  REGION-CENTROID-COL,REGION-CENTROID-ROW,REGION...
# 2  BRICKFACE,140.0,125.0,9,0.0,0.0,0.2777779,0.06...
# 3  BRICKFACE,188.0,133.0,9,0.0,0.0,0.33333334,0.2...
# 4  BRICKFACE,105.0,139.0,9,0.0,0.0,0.27777782,0.1...

# %%
print(data)
# Out:
#                                                                         ;;;  \
# ;;;                                                *-* Last-edit:  11/21/90
# REGION-CENTROID-COL,REGION-CENTROID-ROW,REGION-... NaN NaN              NaN
# BRICKFACE,140.0,125.0,9,0.0,0.0,0.2777779,0.062... NaN NaN              NaN
# BRICKFACE,188.0,133.0,9,0.0,0.0,0.33333334,0.26... NaN NaN              NaN
# BRICKFACE,105.0,139.0,9,0.0,0.0,0.27777782,0.10... NaN NaN              NaN
# ...                                                                     ...
# GRASS,36.0,243.0,9,0.11111111,0.0,1.888889,1.85... NaN NaN              NaN
# GRASS,186.0,218.0,9,0.0,0.0,1.1666666,0.7444442... NaN NaN              NaN
# GRASS,197.0,236.0,9,0.0,0.0,2.4444444,6.829628,... NaN NaN              NaN
# GRASS,208.0,240.0,9,0.11111111,0.0,1.0555557,0.... NaN NaN              NaN
# GRASS,223.0,185.0,9,0.0,0.0,0.5,0.34960312,2.38... NaN NaN              NaN
#
# ...

# %%
data.loc[[3]]
# Out:
#                ;;; -*- Mode:Common-Lisp; Base:10 -*-
# 3  BRICKFACE,188.0,133.0,9,0.0,0.0,0.33333334,0.2...

# %%
data.info(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212 entries, 0 to 211
# Data columns (total 1 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   ;;; -*- Mode:Common-Lisp; Base:10 -*-  212 non-null    object
# dtypes: object(1)
# memory usage: 1.8+ KB

# %%
data.describe()
# Out:
#              ;;;       -*- Mode:Common-Lisp;   Base:10 -*-.1
# count          1         1                 1         1     1
# unique         1         1                 1         1     1
# top     11/21/90  15:28:30                by  Brodley;   *-*
# freq           1         1                 1         1     1

# %%
data.drop(3)
# Out:
#                  ;;; -*- Mode:Common-Lisp; Base:10 -*-
# 0    ;;; *-* Last-edit: 11/21/90 15:28:30 by Brodle...
# 1    REGION-CENTROID-COL,REGION-CENTROID-ROW,REGION...
# 2    BRICKFACE,140.0,125.0,9,0.0,0.0,0.2777779,0.06...
# 4    BRICKFACE,105.0,139.0,9,0.0,0.0,0.27777782,0.1...
# 5    BRICKFACE,34.0,137.0,9,0.0,0.0,0.5000002,0.166...
# ..                                                 ...
# 207  GRASS,36.0,243.0,9,0.11111111,0.0,1.888889,1.8...
# 208  GRASS,186.0,218.0,9,0.0,0.0,1.1666666,0.744444...
# 209  GRASS,197.0,236.0,9,0.0,0.0,2.4444444,6.829628...
# 210  GRASS,208.0,240.0,9,0.11111111,0.0,1.0555557,0...
# 211  GRASS,223.0,185.0,9,0.0,0.0,0.5,0.34960312,2.3...
#
# [211 rows x 1 columns]

# %%
data.loc[[2]]
# Out:
#                ;;; -*- Mode:Common-Lisp; Base:10 -*-
# 2  BRICKFACE,140.0,125.0,9,0.0,0.0,0.2777779,0.06...

# %%
plt.plot(2)
